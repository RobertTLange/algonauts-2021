# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
from mle_toolbox.utils import load_meta_log
import matplotlib.pyplot as plt

# %%
meta_log = load_meta_log("../experiments/21-05-30_base_config/logs/21-05-30_base_config_seed_default.hdf5", False)

# %%
meta_log.seed_default.stats
# Out:
# DotMap(best_bo_score=array([0.3096006 , 0.3096006 , 0.3096006 , 0.3095962 , 0.3095962 ,
#        0.3095962 , 0.3095962 , 0.3095962 , 0.3095962 , 0.3095962 ,
#        0.27855998, 0.27855998, 0.27855998, 0.27855763, 0.27855763,
#        0.27855763, 0.27855763, 0.27855763, 0.27855763, 0.27855763],
#       dtype=float32), corr_mean=array([0.105189  , 0.10516811, 0.10515363, 0.10518992, 0.10515363,
#        0.10515363, 0.10515363, 0.10515401, 0.10516872, 0.10515803,
#        0.14713085, 0.14711364, 0.1471017 , 0.1471316 , 0.1471017 ,
#        0.1471017 , 0.1471017 , 0.14710201, 0.14711414, 0.14710534],
#       dtype=float32), lambda_reg=array([9.6185334e-02, 3.9386205e-02, 5.8714676e-07, 9.8683171e-02,
#        2.6093592e-06, 2.3959865e-05, 2.1255164e-05, 1.0434610e-03,
#        4.1042559e-02, 1.1963700e-02, 9.6185334e-02, 3.9386205e-02,
#        5.8714676e-07, 9.8683171e-02, 2.6093592e-06, 2.3959865e-05,
#        2.1255164e-05, 1.0434610e-03, 4.1042559e-02, 1.1963700e-02],
# ...

# %%
meta_log.seed_default.stats
# Out:
# DotMap(best_bo_score=array([0.3096006 , 0.3096006 , 0.3096006 , 0.3095962 , 0.3095962 ,
#        0.3095962 , 0.3095962 , 0.3095962 , 0.3095962 , 0.3095962 ,
#        0.3095962 , 0.3095962 , 0.30959398, 0.30959398, 0.30959398,
#        0.30959398, 0.30959398, 0.30959398, 0.30959398, 0.30959398,
#        0.30959398, 0.30959398, 0.30959398, 0.30959398, 0.30959398,
#        0.30959398, 0.30959398, 0.30959398, 0.30959398, 0.30959398],
#       dtype=float32), cv_score_mean=array([0.3096006 , 0.30969995, 0.3097689 , 0.3095962 , 0.3097689 ,
#        0.3097689 , 0.3097689 , 0.30976707, 0.309697  , 0.30974796,
#        0.3097689 , 0.3097654 , 0.30959398, 0.3097689 , 0.3097687 ,
#        0.30960742, 0.30959398, 0.3097689 , 0.3097039 , 0.30976772,
#        0.3097685 , 0.30959398, 0.30959398, 0.30959398, 0.30959398,
#        0.30959398, 0.3097689 , 0.30972582, 0.3097689 , 0.30975297],
#       dtype=float32), cv_score_std=array([0.05583105, 0.05594487, 0.05602408, 0.05582604, 0.05602408,
# ...
